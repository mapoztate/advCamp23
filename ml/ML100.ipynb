# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

model = Sequential([Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
# default: ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)
# ML100.1: ys = np.array([-3.1, -0.95, 1.07, 3.03, 4.91, 6.98], dtype=float)
# ML100.2:
ys = np.array([-2, -5, -8, -9, -8, -5], dtype=float)

model.fit(xs, ys, epochs=500)
print(model.predict([10.0]))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 273ms/step - loss: 40.5068
# Epoch 2/500
# 1/1 [==============================] - 0s 14ms/step - loss: 34.9650
# Epoch 3/500
# 1/1 [==============================] - 0s 10ms/step - loss: 30.5603
# Epoch 4/500
# 1/1 [==============================] - 0s 7ms/step - loss: 27.0511
# Epoch 5/500
# 1/1 [==============================] - 0s 7ms/step - loss: 24.2474
# Epoch 6/500
# 1/1 [==============================] - 0s 6ms/step - loss: 21.9996
# Epoch 7/500
# 1/1 [==============================] - 0s 8ms/step - loss: 20.1900
# Epoch 8/500
# 1/1 [==============================] - 0s 8ms/step - loss: 18.7260
# Epoch 9/500
# 1/1 [==============================] - 0s 7ms/step - loss: 17.5348
# Epoch 10/500
# 1/1 [==============================] - 0s 8ms/step - loss: 16.5589
# Epoch 11/500
# 1/1 [==============================] - 0s 8ms/step - loss: 15.7533
# Epoch 12/500
# ...

# %%
# ML 100.3 / 100.4
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from google.colab import files
import tensorflow as tf
import math

# Create noisy data
x_data = np.linspace(-10, 10, num=1000)
y_data = 0.1*x_data*np.cos(x_data) + 0.1*np.random.normal(size=1000)
print('Data created successfully')

# Create the model
model = keras.Sequential()
model.add(keras.layers.Dense(units = 1, activation = 'linear', input_shape=[1]))
model.add(keras.layers.Dense(units = 64, activation = 'relu'))
# model.add(keras.layers.Dense(units = 64, activation = 'relu'))
model.add(keras.layers.Dense(units = 1, activation = 'linear'))
model.compile(loss='mse', optimizer="adam")

# Display the model
model.summary()

# Training
model.fit( x_data, y_data, epochs=100, verbose=1)

# Compute the output
y_predicted = model.predict(x_data)

# Display the result
plt.scatter(x_data[::1], y_data[::1])
plt.plot(x_data, y_predicted, 'r', linewidth=4)
plt.grid()
plt.show()
# Out:
# Data created successfully
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_7 (Dense)             (None, 1)                 2
#
#  dense_8 (Dense)             (None, 64)                128
#
#  dense_9 (Dense)             (None, 1)                 65
#
# ...
# Total params: 195
# Trainable params: 195
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 32/32 [==============================] - 1s 2ms/step - loss: 0.1852
# Epoch 2/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1825
# Epoch 3/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1832
# Epoch 4/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1817
# Epoch 5/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1787
# Epoch 6/100
# ...

# %%
# ML 100.5
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from google.colab import files
import tensorflow as tf
import math

# Create noisy data
x_data = np.linspace(-10, 10, num=1000)
y_data = 0.1*x_data*np.cos(x_data) + 0.1*np.random.normal(size=1000)
print('Data created successfully')

# Create the model
model = keras.Sequential()
model.add(keras.layers.Dense(units = 32, activation = 'linear', input_shape=[1]))
model.add(keras.layers.Dense(units = 64, activation = 'relu'))
model.add(keras.layers.Dense(units = 32, activation = 'linear'))
model.compile(loss='mse', optimizer="adam")

# Display the model
model.summary()

# Training
model.fit( x_data, y_data, epochs=100, verbose=1)

# Compute the output
y_predicted = model.predict(x_data)

# Display the result
plt.scatter(x_data[::1], y_data[::1])
plt.plot(x_data, y_predicted, 'r', linewidth=4)
plt.grid()
plt.show()
# Out:
# Data created successfully
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_10 (Dense)            (None, 32)                64
#
#  dense_11 (Dense)            (None, 64)                2112
#
#  dense_12 (Dense)            (None, 32)                2080
#
# ...
# Total params: 4,256
# Trainable params: 4,256
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 32/32 [==============================] - 1s 2ms/step - loss: 0.4667
# Epoch 2/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1979
# Epoch 3/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1904
# Epoch 4/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1892
# Epoch 5/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1896
# Epoch 6/100
# ...

# %%
# ML 100.6
# Create noisy data
x_data = np.linspace(-10, 10, num=1000)
y_data = 0.1*x_data*np.cos(x_data) + 0.5*np.random.normal(size=1000)
print('Data created successfully')

# Create the model
model = keras.Sequential()
model.add(keras.layers.Dense(units = 1, activation = 'linear', input_shape=[1]))
model.add(keras.layers.Dense(units = 64, activation = 'relu'))
model.add(keras.layers.Dense(units = 64, activation = 'relu'))
model.add(keras.layers.Dense(units = 1, activation = 'linear'))
model.compile(loss='mse', optimizer="adam")

# Display the model
model.summary()

# Training
model.fit( x_data, y_data, epochs=100, verbose=1)

# Compute the output
y_predicted = model.predict(x_data)

# Display the result
plt.scatter(x_data[::1], y_data[::1])
plt.plot(x_data, y_predicted, 'r', linewidth=4)
plt.grid()
plt.show()
# Out:
# Data created successfully
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_21 (Dense)            (None, 1)                 2
#
#  dense_22 (Dense)            (None, 64)                128
#
#  dense_23 (Dense)            (None, 64)                4160
#
#  dense_24 (Dense)            (None, 1)                 65
#
# ...
# Total params: 4,355
# Trainable params: 4,355
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 32/32 [==============================] - 1s 2ms/step - loss: 0.4670
# Epoch 2/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4485
# Epoch 3/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4517
# Epoch 4/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4464
# Epoch 5/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4541
# ...
